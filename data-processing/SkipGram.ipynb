# %%
import numpy as np
np.random.seed(13)

from keras.models import Sequential, Model
from keras.layers import Embedding, Reshape, Activation, Input, Dense
from keras.layers.merge import Dot
from keras.utils import np_utils
from keras.utils.data_utils import get_file
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import skipgrams
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Lecture des données et découpage des parties

# %%
corpus_all = open("./matchseqdata200k.csv").readlines()
corpus = [sentence.split(',')[2:] for sentence in corpus_all]

# %% [markdown]
# Construction du vocabulaires

# %%
cards = np.unique(np.concatenate(corpus))
cards = cards[cards!='\n']
V = len(cards)

# %% [markdown]
# Taille du vocabulaiure

# %%
V
# Out:
# 1660

# %%
cards_dict = dict((cards[i],i) for i in xrange(0, V))

# %%
corpus_num = [[cards_dict[card] for card in game if card!='\n'] for game in corpus]

# %%
vector_dim = 64
input_target = Input((1,), dtype='int32')
input_context = Input((1,), dtype='int32')

embedding_t = Embedding(V, vector_dim, input_length=1, name='embedding_t')
target = embedding_t(input_target)
target = Reshape((vector_dim, 1))(target)
embedding_c = Embedding(V, vector_dim, input_length=1, name='embedding_c')
context = embedding_c(input_context)
context = Reshape((vector_dim, 1))(context)

dot_product = Dot(axes=0)([target, context])
dot_product = Reshape((1,))(dot_product)

output = Dense(1, activation='sigmoid')(dot_product)
SkipGram = Model(inputs=[input_target, input_context], outputs=output)
SkipGram.compile(loss='binary_crossentropy', optimizer='adam')

# %%
import random
def match_ns_generator(corpus_num,nbm):
    while 1:
        Data=[]
        Labels=[]
        for i, doc in enumerate(random.sample(corpus_num,nbm)):
            data, labels = skipgrams(sequence=doc, vocabulary_size=V, window_size=3, negative_samples=2.)
            if (len(data)>0):
                Data.append(np.array(data, dtype=np.int32))
                Labels.append(np.array(labels, dtype=np.int32))
        Data=np.concatenate(Data)
        Labels=np.concatenate(Labels)
        x=[Data[:,0],Data[:,1]]
        y=Labels
        yield (x,y)

# %%
hist=SkipGram.fit_generator(match_ns_generator(corpus_num,10),200,100)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s - loss: 0.6256
# Epoch 2/100
# 200/200 [==============================] - 1s - loss: 0.3620
# Epoch 3/100
# 200/200 [==============================] - 1s - loss: 0.2803
# Epoch 4/100
# 200/200 [==============================] - 1s - loss: 0.2567
# Epoch 5/100
# 200/200 [==============================] - 1s - loss: 0.2385
# Epoch 6/100
# 200/200 [==============================] - 1s - loss: 0.2280
# Epoch 7/100
# 200/200 [==============================] - 1s - loss: 0.2231
# Epoch 8/100
# 200/200 [==============================] - 1s - loss: 0.2158
# Epoch 9/100
# 200/200 [==============================] - 1s - loss: 0.2082
# Epoch 10/100
# 200/200 [==============================] - 1s - loss: 0.2055
# Epoch 11/100
# 200/200 [==============================] - 1s - loss: 0.2013
# Epoch 12/100
# 200/200 [==============================] - 1s - loss: 0.1957
# Epoch 13/100
# 200/200 [==============================] - 1s - loss: 0.2019
# Epoch 14/100
# 200/200 [==============================] - 1s - loss: 0.2012
# Epoch 15/100
# 200/200 [==============================] - 1s - loss: 0.1954
# Epoch 16/100
# 200/200 [==============================] - 1s - loss: 0.1917
# Epoch 17/100
# 200/200 [==============================] - 1s - loss: 0.1961
# Epoch 18/100
# 200/200 [==============================] - 1s - loss: 0.1968
# Epoch 19/100
# 200/200 [==============================] - 1s - loss: 0.1952
# Epoch 20/100
# 200/200 [==============================] - 1s - loss: 0.1905
# Epoch 21/100
# 200/200 [==============================] - 1s - loss: 0.1909
# Epoch 22/100
# 200/200 [==============================] - 1s - loss: 0.1950
# Epoch 23/100
# 200/200 [==============================] - 1s - loss: 0.1919
# Epoch 24/100
# 200/200 [==============================] - 1s - loss: 0.1908
# Epoch 25/100
# 200/200 [==============================] - 1s - loss: 0.1917
# Epoch 26/100
# 200/200 [==============================] - 1s - loss: 0.1892
# Epoch 27/100
# 200/200 [==============================] - 1s - loss: 0.1930
# Epoch 28/100
# 200/200 [==============================] - 1s - loss: 0.1892
# Epoch 29/100
# 200/200 [==============================] - 1s - loss: 0.1927
# Epoch 30/100
# 200/200 [==============================] - 1s - loss: 0.1891
# Epoch 31/100
# 200/200 [==============================] - 1s - loss: 0.1862
# Epoch 32/100
# 200/200 [==============================] - 1s - loss: 0.1870
# Epoch 33/100
# 200/200 [==============================] - 1s - loss: 0.1877
# Epoch 34/100
# 200/200 [==============================] - 1s - loss: 0.1873
# Epoch 35/100
# 200/200 [==============================] - 1s - loss: 0.1896
# Epoch 36/100
# 200/200 [==============================] - 1s - loss: 0.1866
# Epoch 37/100
# 200/200 [==============================] - 1s - loss: 0.1818
# Epoch 38/100
# 200/200 [==============================] - 1s - loss: 0.1888
# Epoch 39/100
# 200/200 [==============================] - 1s - loss: 0.1840
# Epoch 40/100
# 200/200 [==============================] - 1s - loss: 0.1908
# Epoch 41/100
# 200/200 [==============================] - 1s - loss: 0.1809
# Epoch 42/100
# 200/200 [==============================] - 1s - loss: 0.1838
# Epoch 43/100
# 200/200 [==============================] - 1s - loss: 0.1855
# Epoch 44/100
# 200/200 [==============================] - 1s - loss: 0.1910
# Epoch 45/100
# 200/200 [==============================] - 1s - loss: 0.1853
# Epoch 46/100
# 200/200 [==============================] - 1s - loss: 0.1865
# Epoch 47/100
# 200/200 [==============================] - 1s - loss: 0.1828
# Epoch 48/100
# 200/200 [==============================] - 1s - loss: 0.1898
# Epoch 49/100
# 200/200 [==============================] - 1s - loss: 0.1885
# Epoch 50/100
# 200/200 [==============================] - 1s - loss: 0.1826
# Epoch 51/100
# 200/200 [==============================] - 1s - loss: 0.1860
# Epoch 52/100
# 200/200 [==============================] - 1s - loss: 0.1874
# Epoch 53/100
# 200/200 [==============================] - 1s - loss: 0.1828
# Epoch 54/100
# 200/200 [==============================] - 1s - loss: 0.1845
# Epoch 55/100
# 200/200 [==============================] - 1s - loss: 0.1867
# Epoch 56/100
# 200/200 [==============================] - 1s - loss: 0.1854
# Epoch 57/100
# 200/200 [==============================] - 1s - loss: 0.1816
# Epoch 58/100
# 200/200 [==============================] - 1s - loss: 0.1865
# Epoch 59/100
# 200/200 [==============================] - 1s - loss: 0.1844
# Epoch 60/100
# 200/200 [==============================] - 1s - loss: 0.1860
# Epoch 61/100
# 200/200 [==============================] - 1s - loss: 0.1847
# Epoch 62/100
# 200/200 [==============================] - 1s - loss: 0.1863
# Epoch 63/100
# 200/200 [==============================] - 1s - loss: 0.1823
# Epoch 64/100
# 200/200 [==============================] - 1s - loss: 0.1836
# Epoch 65/100
# 200/200 [==============================] - 1s - loss: 0.1826
# Epoch 66/100
# 200/200 [==============================] - 1s - loss: 0.1851
# Epoch 67/100
# 200/200 [==============================] - 1s - loss: 0.1770
# Epoch 68/100
# 200/200 [==============================] - 1s - loss: 0.1834
# Epoch 69/100
# 200/200 [==============================] - 1s - loss: 0.1819
# Epoch 70/100
# 200/200 [==============================] - 1s - loss: 0.1831
# Epoch 71/100
# 200/200 [==============================] - 1s - loss: 0.1786
# Epoch 72/100
# 200/200 [==============================] - 1s - loss: 0.1857
# Epoch 73/100
# 200/200 [==============================] - 1s - loss: 0.1828
# Epoch 74/100
# 200/200 [==============================] - 1s - loss: 0.1814
# Epoch 75/100
# 200/200 [==============================] - 1s - loss: 0.1853
# Epoch 76/100
# 200/200 [==============================] - 1s - loss: 0.1837
# Epoch 77/100
# 200/200 [==============================] - 1s - loss: 0.1836
# Epoch 78/100
# 200/200 [==============================] - 1s - loss: 0.1819
# Epoch 79/100
# 200/200 [==============================] - 1s - loss: 0.1828
# Epoch 80/100
# 200/200 [==============================] - 1s - loss: 0.1799
# Epoch 81/100
# 200/200 [==============================] - 1s - loss: 0.1799
# Epoch 82/100
# 200/200 [==============================] - 1s - loss: 0.1778
# Epoch 83/100
# 200/200 [==============================] - 1s - loss: 0.1818
# Epoch 84/100
# 200/200 [==============================] - 1s - loss: 0.1794
# Epoch 85/100
# 200/200 [==============================] - 1s - loss: 0.1806
# Epoch 86/100
# 200/200 [==============================] - 1s - loss: 0.1838
# Epoch 87/100
# 200/200 [==============================] - 1s - loss: 0.1798
# Epoch 88/100
# 200/200 [==============================] - 1s - loss: 0.1793
# Epoch 89/100
# 200/200 [==============================] - 1s - loss: 0.1777
# Epoch 90/100
# 200/200 [==============================] - 1s - loss: 0.1786
# Epoch 91/100
# 200/200 [==============================] - 1s - loss: 0.1798
# Epoch 92/100
# 200/200 [==============================] - 1s - loss: 0.1776
# Epoch 93/100
# 200/200 [==============================] - 1s - loss: 0.1783
# Epoch 94/100
# 200/200 [==============================] - 1s - loss: 0.1833
# Epoch 95/100
# 200/200 [==============================] - 1s - loss: 0.1793
# Epoch 96/100
# 200/200 [==============================] - 1s - loss: 0.1795
# Epoch 97/100
# 200/200 [==============================] - 1s - loss: 0.1772
# Epoch 98/100
# 200/200 [==============================] - 1s - loss: 0.1826
# Epoch 99/100
# 200/200 [==============================] - 1s - loss: 0.1742
# Epoch 100/100
# 200/200 [==============================] - 1s - loss: 0.1776

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
mpl.rcParams['figure.figsize'] = (16,8)

# %%
plt.plot(hist.history['loss'])

# %%
f = open('vectors200k.txt' ,'w')
f.write('{} {}\n'.format(V-1, vector_dim))
vectors = SkipGram.get_weights()[0]
for i, word in enumerate(cards):
    f.write('{} {}\n'.format(word.replace(" ","_"), ' '.join(map(str, list(vectors[i, :])))))
f.close()

# %%
import pandas as pd
meta=pd.read_json("cards_meta.json")
meta
# Out:
#       armor                   artist  attack cardClass classes  collectible  \
# 0       NaN      Nutthapon Petchthai     NaN      MAGE     NaN          1.0
# 1       NaN                    Tooth     NaN      MAGE     NaN          1.0
# 2       NaN          Arthur Bozonnet     3.0      MAGE     NaN          1.0
# 3       NaN           Gabor Szikszai     NaN      MAGE     NaN          1.0
# 4       NaN                Mike Sass     NaN      MAGE     NaN          1.0
# 5       NaN                      NaN     4.0   NEUTRAL     NaN          NaN
# 6       NaN                Dan Scott     3.0      MAGE     NaN          1.0
# 7       NaN                      NaN     NaN      MAGE     NaN          NaN
# 8       NaN               Andrew Hou     3.0      MAGE     NaN          1.0
# 9       NaN      Christopher Moeller     6.0      MAGE     NaN          1.0
# 10      NaN           Zoltan & Gabor     7.0      MAGE     NaN          1.0
# 11      NaN        Brandon Kitkouski     3.0    HUNTER     NaN          1.0
# 12      NaN              Alex Garner     3.0    PRIEST     NaN          1.0
# 13      NaN                      NaN     NaN   NEUTRAL     NaN          NaN
# 14      NaN              Dave Allsop     5.0    PRIEST     NaN          1.0
# 15      NaN                Mike Sass     NaN    PRIEST     NaN          1.0
# 16      NaN                      NaN     NaN   NEUTRAL     NaN          NaN
# 17      NaN              Warren Mahy     3.0    PRIEST     NaN          1.0
# 18      NaN                      NaN     NaN    PRIEST     NaN          NaN
# 19      NaN           Dan Dos Santos     NaN    PRIEST     NaN          1.0
# 20      NaN           Sean O'Danield     NaN    PRIEST     NaN          1.0
# 21      NaN                      NaN     NaN    PRIEST     NaN          NaN
# 22      NaN          Slawomir Maniak     2.0   NEUTRAL     NaN          1.0
# 23      NaN                      NaN     NaN   NEUTRAL     NaN          NaN
# 24      NaN               Chris Rahn     5.0    PRIEST     NaN          1.0
# 25      NaN   Alex Horley Orlandelli     1.0   WARLOCK     NaN          1.0
# 26      NaN                      NaN     NaN   NEUTRAL     NaN          NaN
# 27      NaN            Anton Zemskov     6.0   WARLOCK     NaN          1.0
# 28      NaN         Raymond Swanland     3.0   WARLOCK     NaN          1.0
# 29      NaN                      NaN     NaN   WARLOCK     NaN          NaN
# ...     ...                      ...     ...       ...     ...          ...
# 3444    NaN               Matt Gaser     NaN      MAGE     NaN          1.0
# 3445    NaN         Hideaki Takamura     NaN    SHAMAN     NaN          1.0
# 3446    NaN         Hideaki Takamura     NaN    SHAMAN     NaN          NaN
# 3447    NaN          Peter Stapleton     3.0   WARRIOR     NaN          1.0
# 3448    NaN          Peter Stapleton     6.0   WARRIOR     NaN          NaN
# 3449    NaN             Zoltan Boros     NaN   PALADIN     NaN          1.0
# 3450    NaN         Hideaki Takamura     NaN   PALADIN     NaN          1.0
# 3451    NaN                Dan Scott     3.0   PALADIN     NaN          1.0
# 3452    NaN            Phil Saunders     3.0    PRIEST     NaN          1.0
# 3453    NaN          Slawomir Maniak     NaN   NEUTRAL     NaN          NaN
# 3454    NaN          Slawomir Maniak     NaN   NEUTRAL     NaN          NaN
# 3455    NaN         Mauricio Herrera     NaN   NEUTRAL     NaN          NaN
# 3456    NaN         Mauricio Herrera     NaN   NEUTRAL     NaN          NaN
# 3457    NaN            Rudy Siswanto     NaN   NEUTRAL     NaN          NaN
# 3458    NaN            Rudy Siswanto     NaN   NEUTRAL     NaN          NaN
# 3459    NaN             Zoltan Boros     NaN   NEUTRAL     NaN          NaN
# 3460    NaN             Zoltan Boros     NaN   NEUTRAL     NaN          NaN
# 3461    NaN             Zoltan Boros     1.0   NEUTRAL     NaN          NaN
# 3462    NaN            Garrett Hanna     NaN   NEUTRAL     NaN          NaN
# 3463    NaN            Garrett Hanna     NaN   NEUTRAL     NaN          NaN
# 3464    NaN        Arthur Gimaldinov     NaN   NEUTRAL     NaN          NaN
# 3465    NaN        Arthur Gimaldinov     NaN   NEUTRAL     NaN          NaN
# 3466    NaN             Jakub Kasber     NaN   NEUTRAL     NaN          NaN
# 3467    NaN             Jakub Kasber     NaN   NEUTRAL     NaN          NaN
# 3468    NaN       Konstantin Turovec     NaN   NEUTRAL     NaN          NaN
# 3469    NaN       Konstantin Turovec     NaN   NEUTRAL     NaN          NaN
# 3470    NaN              James Ryman     NaN   NEUTRAL     NaN          NaN
# 3471    NaN              James Ryman     NaN   NEUTRAL     NaN          NaN
# 3472    NaN  L. Lullabi & K. Turovec     NaN   NEUTRAL     NaN          NaN
# 3473    NaN  L. Lullabi & K. Turovec     NaN   NEUTRAL     NaN          NaN
#
#      collectionText  cost    dbfId  durability     ...       \
# 0               NaN   5.0   2539.0         NaN     ...
# 1               NaN   3.0   2541.0         NaN     ...
# 2               NaN   2.0   2545.0         NaN     ...
# 3               NaN   1.0   2572.0         NaN     ...
# 4               NaN   3.0   2542.0         NaN     ...
# 5               NaN   3.0   2543.0         NaN     ...
# 6               NaN   4.0   2549.0         NaN     ...
# 7               NaN   NaN   2550.0         NaN     ...
# 8               NaN   3.0   2571.0         NaN     ...
# 9               NaN   6.0   2544.0         NaN     ...
# 10              NaN   8.0   2546.0         NaN     ...
# 11              NaN   5.0   2552.0         NaN     ...
# 12              NaN   4.0   2555.0         NaN     ...
# 13              NaN   NaN   2846.0         NaN     ...
# 14              NaN   4.0   2551.0         NaN     ...
# 15              NaN   1.0   2568.0         NaN     ...
# 16              NaN   NaN   2848.0         NaN     ...
# 17              NaN   3.0   2566.0         NaN     ...
# 18              NaN   NaN   2567.0         NaN     ...
# 19              NaN   2.0   2563.0         NaN     ...
# 20              NaN   2.0   2564.0         NaN     ...
# 21              NaN   NaN   2565.0         NaN     ...
# 22              NaN   4.0   2569.0         NaN     ...
# 23              NaN   NaN   2570.0         NaN     ...
# 24              NaN   7.0   2556.0         NaN     ...
# 25              NaN   4.0   2822.0         NaN     ...
# 26              NaN   NaN  47218.0         NaN     ...
# 27              NaN   7.0   2624.0         NaN     ...
# 28              NaN   2.0   2777.0         NaN     ...
# 29              NaN   NaN   2778.0         NaN     ...
# ...             ...   ...      ...         ...     ...
# 3444            NaN   6.0  41878.0         NaN     ...
# 3445            NaN   3.0  41879.0         NaN     ...
# 3446            NaN   NaN  42037.0         NaN     ...
# 3447            NaN   5.0  41890.0         NaN     ...
# 3448            NaN   5.0  41889.0         NaN     ...
# 3449            NaN   1.0  41912.0         NaN     ...
# 3450            NaN   1.0  41944.0         NaN     ...
# 3451            NaN   4.0  41945.0         NaN     ...
# 3452            NaN   5.0  42046.0         NaN     ...
# 3453            NaN   0.0  41054.0         NaN     ...
# 3454            NaN   NaN  41065.0         NaN     ...
# 3455            NaN   0.0  41211.0         NaN     ...
# 3456            NaN   NaN  41210.0         NaN     ...
# 3457            NaN   0.0  41691.0         NaN     ...
# 3458            NaN   NaN  41692.0         NaN     ...
# 3459            NaN   0.0  41057.0         NaN     ...
# 3460            NaN   NaN  41693.0         NaN     ...
# 3461            NaN   1.0  41067.0         NaN     ...
# 3462            NaN   0.0  41058.0         NaN     ...
# 3463            NaN   NaN  41068.0         NaN     ...
# 3464            NaN   0.0  41059.0         NaN     ...
# 3465            NaN   NaN  41069.0         NaN     ...
# 3466            NaN   0.0  41060.0         NaN     ...
# 3467            NaN   NaN  41070.0         NaN     ...
# 3468            NaN   0.0  41061.0         NaN     ...
# 3469            NaN   NaN  41071.0         NaN     ...
# 3470            NaN   0.0  41062.0         NaN     ...
# 3471            NaN   NaN  41072.0         NaN     ...
# 3472            NaN   0.0  41063.0         NaN     ...
# 3473            NaN   NaN  41073.0         NaN     ...
#
#                                        playRequirements playerClass  \
# 0     {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...        MAGE
# 1                                                   NaN        MAGE
# 2                                                   NaN        MAGE
# 3     {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...        MAGE
# 4     {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...        MAGE
# 5                                                   NaN     NEUTRAL
# 6                                                   NaN        MAGE
# 7                                                   NaN        MAGE
# 8                                                   NaN        MAGE
# 9                                                   NaN        MAGE
# 10                                                  NaN        MAGE
# 11                                                  NaN      HUNTER
# 12                                                  NaN      PRIEST
# 13                                                  NaN     NEUTRAL
# 14                                                  NaN      PRIEST
# 15    {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...      PRIEST
# 16                                                  NaN     NEUTRAL
# 17                                                  NaN      PRIEST
# 18                                                  NaN      PRIEST
# 19    {u'REQ_TARGET_TO_PLAY': 0, u'REQ_MINION_TARGET...      PRIEST
# 20                                                  NaN      PRIEST
# 21                                                  NaN      PRIEST
# 22                                                  NaN     NEUTRAL
# 23                                                  NaN     NEUTRAL
# 24                                                  NaN      PRIEST
# 25                                                  NaN     WARLOCK
# 26                                                  NaN     NEUTRAL
# 27                                                  NaN     WARLOCK
# 28                                                  NaN     WARLOCK
# 29                                                  NaN     WARLOCK
# ...                                                 ...         ...
# 3444  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...        MAGE
# 3445                                                NaN      SHAMAN
# 3446                                                NaN      SHAMAN
# 3447                                                NaN     WARRIOR
# 3448                                                NaN     WARRIOR
# 3449                       {u'REQ_NUM_MINION_SLOTS': 1}     PALADIN
# 3450  {u'REQ_FRIENDLY_TARGET': 0, u'REQ_MINION_TARGE...     PALADIN
# 3451                                                NaN     PALADIN
# 3452                                                NaN      PRIEST
# 3453  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3454                                                NaN     NEUTRAL
# 3455  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3456                                                NaN     NEUTRAL
# 3457  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3458                                                NaN     NEUTRAL
# 3459  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3460                                                NaN     NEUTRAL
# 3461                                                NaN     NEUTRAL
# 3462  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3463                                                NaN     NEUTRAL
# 3464  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3465                                                NaN     NEUTRAL
# 3466  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3467                                                NaN     NEUTRAL
# 3468  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3469                                                NaN     NEUTRAL
# 3470  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3471                                                NaN     NEUTRAL
# 3472  {u'REQ_MINION_TARGET': 0, u'REQ_TARGET_TO_PLAY...     NEUTRAL
# 3473                                                NaN     NEUTRAL
#
#            race     rarity  referencedTags     set spellDamage  \
# 0           NaN     COMMON             NaN     TGT         NaN
# 1           NaN       RARE             NaN     TGT         NaN
# 2           NaN       RARE             NaN     TGT         NaN
# 3           NaN       EPIC    [SPELLPOWER]     TGT         NaN
# 4           NaN       RARE        [CHARGE]     TGT         NaN
# 5         BEAST        NaN             NaN     TGT         NaN
# 6           NaN     COMMON    [SPELLPOWER]     TGT         NaN
# 7           NaN        NaN             NaN     TGT         NaN
# 8           NaN     COMMON             NaN     TGT         NaN
# 9        DRAGON       EPIC             NaN     TGT         NaN
# 10          NaN  LEGENDARY             NaN     TGT         NaN
# 11          NaN       RARE             NaN     TGT         NaN
# 12          NaN     COMMON             NaN     TGT         NaN
# 13          NaN        NaN             NaN     TGT         NaN
# 14          NaN       RARE             NaN     TGT         NaN
# 15          NaN     COMMON             NaN     TGT         NaN
# 16          NaN        NaN             NaN     TGT         NaN
# 17          NaN       EPIC             NaN     TGT         NaN
# 18          NaN        NaN             NaN     TGT         NaN
# 19          NaN       RARE             NaN     TGT         NaN
# 20          NaN       EPIC             NaN     TGT         NaN
# 21          NaN        NaN             NaN     TGT         NaN
# 22       DRAGON       EPIC         [TAUNT]     TGT         NaN
# 23          NaN        NaN             NaN     TGT         NaN
# 24          NaN  LEGENDARY             NaN     TGT         NaN
# 25        DEMON       EPIC             NaN     TGT         NaN
# 26          NaN        NaN             NaN     TGT         NaN
# 27        DEMON     COMMON             NaN     TGT         NaN
# 28        DEMON       RARE             NaN     TGT         NaN
# 29          NaN        NaN             NaN     TGT         NaN
# ...         ...        ...             ...     ...         ...
# 3444        NaN       EPIC             NaN  UNGORO         NaN
# 3445        NaN       EPIC   [DEATHRATTLE]  UNGORO         NaN
# 3446        NaN        NaN             NaN  UNGORO         NaN
# 3447      BEAST       RARE             NaN  UNGORO         NaN
# 3448      BEAST        NaN             NaN  UNGORO         NaN
# 3449        NaN     COMMON             NaN  UNGORO         NaN
# 3450        NaN     COMMON         [ADAPT]  UNGORO         NaN
# 3451      BEAST       RARE         [ADAPT]  UNGORO         NaN
# 3452  ELEMENTAL  LEGENDARY             NaN  UNGORO         NaN
# 3453        NaN        NaN             NaN  UNGORO         NaN
# 3454        NaN        NaN             NaN  UNGORO         NaN
# 3455        NaN        NaN             NaN  UNGORO         NaN
# 3456        NaN        NaN             NaN  UNGORO         NaN
# 3457        NaN        NaN             NaN  UNGORO         NaN
# 3458        NaN        NaN             NaN  UNGORO         NaN
# 3459        NaN        NaN             NaN  UNGORO         NaN
# 3460        NaN        NaN             NaN  UNGORO         NaN
# 3461        NaN        NaN             NaN  UNGORO         NaN
# 3462        NaN        NaN             NaN  UNGORO         NaN
# 3463        NaN        NaN             NaN  UNGORO         NaN
# 3464        NaN        NaN             NaN  UNGORO         NaN
# 3465        NaN        NaN             NaN  UNGORO         NaN
# 3466        NaN        NaN             NaN  UNGORO         NaN
# 3467        NaN        NaN             NaN  UNGORO         NaN
# 3468        NaN        NaN             NaN  UNGORO         NaN
# 3469        NaN        NaN             NaN  UNGORO         NaN
# 3470        NaN        NaN             NaN  UNGORO         NaN
# 3471        NaN        NaN             NaN  UNGORO         NaN
# 3472        NaN        NaN             NaN  UNGORO         NaN
# 3473        NaN        NaN             NaN  UNGORO         NaN
#
#      targetingArrowText                                               text  \
# 0                   NaN                        Deal $8 damage to a minion.
# 1                   NaN  <b>Secret:</b> When a friendly minion dies, su...
# 2                   NaN              Your Hero Power deals 1 extra damage.
# 3                   NaN  Deal $2 damage to a minion. This spell gets do...
# 4                   NaN  Transform a minion into a 4/2 Boar with <b>Cha...
# 5                   NaN                                      <b>Charge</b>
# 6                   NaN       <b>Inspire:</b> Gain <b>Spell Damage +1</b>.
# 7                   NaN                            Increased Spell Damage.
# 8                   NaN  <b>Battlecry:</b> Add a random spell to each p...
# 9                   NaN   You can use your Hero Power any number of times.
# 10                  NaN  <b>Deathrattle:</b> Add 3 copies of Arcane Mis...
# 11                  NaN  <b>Battlecry:</b> If you have a Beast, summon ...
# 12                  NaN    Whenever a character is healed, gain +2 Attack.
# 13                  NaN                                  Increased Attack.
# 14                  NaN        <b>Inspire:</b> Deal 4 damage to each hero.
# 15                  NaN  Choose a minion. Whenever it attacks, restore ...
# 16                  NaN  When this attacks, restore 4 Health to the her...
# 17                  NaN  Whenever you draw a card, reduce its Cost by (1).
# 18                  NaN                                    Costs (1) less.
# 19                  NaN      Put a copy of an enemy minion into your hand.
# 20                  NaN         Swap the Attack and Health of all minions.
# 21                  NaN                         Swapped Attack and Health.
# 22                  NaN  <b>Battlecry:</b> If you're holding a Dragon, ...
# 23                  NaN                        +1 Attack and <b>Taunt</b>.
# 24                  NaN  <b>Inspire:</b> Summon a random <b>Legendary</...
# 25                  NaN  <b>Deathrattle:</b> At the end\n of the turn, ...
# 26                  NaN        Summon a Dreadsteed at the end of the turn.
# 27                  NaN                                                NaN
# 28                  NaN           Whenever you discard a card, gain +1/+1.
# 29                  NaN                                   Increased stats.
# ...                 ...                                                ...
# 3444                NaN  Deal $15 damage to a minion and $3 damage to a...
# 3445                NaN  Give your minions "<b>Deathrattle:</b> Return ...
# 3446                NaN           <b>Deathrattle:</b> Return to your hand.
# 3447                NaN  <b>Taunt</b>\n<b>Deathrattle:</b> Shuffle a 6/...
# 3448                NaN                                       <b>Taunt</b>
# 3449                NaN               Summon two 1/1 Silver Hand Recruits.
# 3450                NaN                    <b>Adapt</b> a friendly minion.
# 3451                NaN  <b>Battlecry:</b> <b>Adapt</b> your Silver Han...
# 3452                NaN  Whenever you cast a spell, add a random Priest...
# 3453                NaN               <b>Stealth</b> until your next turn.
# 3454                NaN                    Stealthed until your next turn.
# 3455                NaN                                   <b>Poisonous</b>
# 3456                NaN                                   <b>Poisonous</b>
# 3457                NaN                                              +1/+1
# 3458                NaN                                             +1/+1.
# 3459                NaN         <b>Deathrattle:</b> Summon two 1/1 Plants.
# 3460                NaN         <b>Deathrattle:</b> Summon two 1/1 Plants.
# 3461                NaN                                                NaN
# 3462                NaN                                          +3 Attack
# 3463                NaN                                         +3 Attack.
# 3464                NaN                                          +3 Health
# 3465                NaN                                         +3 Health.
# 3466                NaN        Can't be targeted by spells or Hero Powers.
# 3467                NaN        Can't be targeted by spells or Hero Powers.
# 3468                NaN                                       <b>Taunt</b>
# 3469                NaN                                       <b>Taunt</b>
# 3470                NaN                                    <b>Windfury</b>
# 3471                NaN                                    <b>Windfury</b>
# 3472                NaN                               <b>Divine Shield</b>
# 3473                NaN                               <b>Divine Shield</b>
#
#              type
# 0           SPELL
# 1           SPELL
# 2          MINION
# 3           SPELL
# 4           SPELL
# 5          MINION
# 6          MINION
# 7     ENCHANTMENT
# 8          MINION
# 9          MINION
# 10         MINION
# 11         MINION
# 12         MINION
# 13    ENCHANTMENT
# 14         MINION
# 15          SPELL
# 16    ENCHANTMENT
# 17         MINION
# 18    ENCHANTMENT
# 19          SPELL
# 20          SPELL
# 21    ENCHANTMENT
# 22         MINION
# 23    ENCHANTMENT
# 24         MINION
# 25         MINION
# 26    ENCHANTMENT
# 27         MINION
# 28         MINION
# 29    ENCHANTMENT
# ...           ...
# 3444        SPELL
# 3445        SPELL
# 3446  ENCHANTMENT
# 3447       MINION
# 3448       MINION
# 3449        SPELL
# 3450        SPELL
# 3451       MINION
# 3452       MINION
# 3453        SPELL
# 3454  ENCHANTMENT
# 3455        SPELL
# 3456  ENCHANTMENT
# 3457        SPELL
# 3458  ENCHANTMENT
# 3459        SPELL
# 3460  ENCHANTMENT
# 3461       MINION
# 3462        SPELL
# 3463  ENCHANTMENT
# 3464        SPELL
# 3465  ENCHANTMENT
# 3466        SPELL
# 3467  ENCHANTMENT
# 3468        SPELL
# 3469  ENCHANTMENT
# 3470        SPELL
# 3471  ENCHANTMENT
# 3472        SPELL
# 3473  ENCHANTMENT
#
# [3474 rows x 33 columns]

# %%
vectors = SkipGram.get_weights()[0]
useCards=pd.DataFrame({'name':cards,'v0':vectors[:,0],'v1':vectors[:,1],'v2':vectors[:,2]})
meta_sub=pd.merge(useCards,meta.drop_duplicates('name'),on='name')

# %%
classes=meta_sub["cardClass"].unique()
class_dict=dict((classes[i],i) for i in range(len(classes)))
meta_sub["card_class_num"]=meta_sub["cardClass"].apply(lambda c:class_dict[c])
cm=plt.get_cmap("tab20")

# %%
plt.scatter(meta_sub["v0"],meta_sub["v1"],s=meta_sub["cost"]*10,color=cm(meta_sub["card_class_num"]))

# %%
plt.scatter(meta_sub["v0"],meta_sub["v2"],s=meta_sub["cost"]*10,color=cm(meta_sub["card_class_num"]))

# %%
import numpy as np
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(vectors)
X_embedded.shape
# Out:
# (1660, 2)

# %%
useCards=pd.DataFrame({'name':cards,'t0':X_embedded[:,0],'t1':X_embedded[:,1]})
meta_sub=pd.merge(useCards,meta.drop_duplicates('name'),on='name')

# %%
classes=meta_sub["cardClass"].unique()
class_dict=dict((classes[i],i) for i in range(len(classes)))
meta_sub["card_class_num"]=meta_sub["cardClass"].apply(lambda c:class_dict[c])
cm=plt.get_cmap("tab20")
plt.scatter(meta_sub["t0"],meta_sub["t1"],s=meta_sub["cost"]*10,color=cm(meta_sub["card_class_num"]))

# %%
pdv=pd.DataFrame(vectors)
pdv["name"]=cards
sub=pd.merge(pdv,meta[["name","cardClass"]].drop_duplicates('name'),on='name')
sub=sub.loc[(sub["cardClass"]=="NEUTRAL") | (sub["cardClass"]=="HUNTER"),]

# %%
vsub=np.array(sub.iloc[:,:64])
X_emb_sub = TSNE(n_components=2).fit_transform(vsub)

# %%
sub["card_class_num"]=sub["cardClass"].apply(lambda c:class_dict[c])
cm=plt.get_cmap("tab20")
plt.scatter(X_emb_sub[:,0],X_emb_sub[:,1],s=12,color=cm(sub["card_class_num"]))

# %%
meta_sub.to_csv("skip_gram_tsne200k.csv", encoding="UTF-8")

# %%
meta_sub.to_json("skip_gram_tsne200k.json")

# %%
np.unique(meta_sub["type"])
# Out:
# array([u'ENCHANTMENT', u'HERO', u'HERO_POWER', u'MINION', u'SPELL',
#        u'WEAPON'], dtype=object)

# %%
meta_sub.loc[meta_sub["type"]=='HERO_POWER',["name","dbfId","cardClass"]]
# Out:
#                    name    dbfId cardClass
# 83            Armor Up!    725.0   WARRIOR
# 109       Ballista Shot   2738.0    HUNTER
# 142           Blackwing   2349.0   NEUTRAL
# 148          Bladestorm  45585.0   WARRIOR
# 208       Build-A-Beast  43183.0   NEUTRAL
# 311      Dagger Mastery    730.0     ROGUE
# 373     Dire Shapeshift   2737.0     DRUID
# 526           Fireblast    807.0      MAGE
# 527    Fireblast Rank 2   2739.0      MAGE
# 572         Frost Blast   1901.0   NEUTRAL
# 673                Heal   2741.0    PRIEST
# 716            INFERNO!   1178.0   WARLOCK
# 728           Icy Touch  42944.0   NEUTRAL
# 772       Jeering Crowd   2317.0   NEUTRAL
# 839         Lesser Heal    479.0    PRIEST
# 840            Life Tap    300.0   WARLOCK
# 848      Lightning Jolt   2803.0    SHAMAN
# 943        Mind Shatter   1623.0    PRIEST
# 944          Mind Spike   1622.0    PRIEST
# 1031          Old Horde   2347.0   NEUTRAL
# 1039     Open the Gates   2345.0   NEUTRAL
# 1064        Plague Lord  43182.0   NEUTRAL
# 1071   Poisoned Daggers   2743.0     ROGUE
# 1152          Reinforce    472.0   PALADIN
# 1247         Shapeshift   1123.0     DRUID
# 1283        Siphon Life  43181.0   NEUTRAL
# 1315           Soul Tap   2744.0   WARLOCK
# 1356        Steady Shot    229.0    HUNTER
# 1402           Tank Up!   2745.0   WARRIOR
# 1422  The Four Horsemen  43013.0   NEUTRAL
# 1429    The Silver Hand   2740.0   PALADIN
# 1432     The Tidal Hand  39154.0   PALADIN
# 1464       Totemic Call    687.0    SHAMAN
# 1466       Totemic Slam   2742.0    SHAMAN
# 1474   Transmute Spirit  42982.0   NEUTRAL
# 1552           Voidform  45397.0    PRIEST

# %% [markdown]
# # Analyse de l'exapce vectoriel de description

# %% [markdown]
# ## Quelques exemple de requêtes similarité / analogie

# %%
import gensim
w2v = gensim.models.KeyedVectors.load_word2vec_format('./vectors200k.txt', binary=False)

# %%
w2v.most_similar(positive=['Armor_Up!'])
# Out:
# [(u'Fiery_War_Axe', 0.8980605602264404),
#  (u'Brawl', 0.7869135141372681),
#  (u'Ravaging_Ghoul', 0.7867157459259033),
#  (u'Forge_of_Souls', 0.7834479212760925),
#  (u'Crush', 0.7819375395774841),
#  (u'Shield_Block', 0.7800502777099609),
#  (u'Bash', 0.7760571241378784),
#  (u'Bloodhoof_Brave', 0.7752119302749634),
#  (u"Death's_Bite", 0.7723432779312134),
#  (u'Slam', 0.7712208032608032)]

# %%
sim=w2v.most_similar(positive=['Steady_Shot', 'Varian_Wrynn'], negative=['Armor_Up!'])
tt=pd.DataFrame(sim)
sim_df=pd.DataFrame({"name":tt[0].apply(lambda n:n.replace("_"," ")),"sim":tt[1]})
sim_df=pd.merge(sim_df,meta.drop_duplicates('name'),on='name')
sim_df[["name","sim","cardClass","type","cost","attack","health","text"]]
# Out:
#                   name       sim cardClass    type  cost  attack  health  \
# 0              Acidmaw  0.674603    HUNTER  MINION   7.0     4.0     2.0
# 1      Ball of Spiders  0.669722    HUNTER   SPELL   6.0     NaN     NaN
# 2        Bestial Wrath  0.660563    HUNTER   SPELL   1.0     NaN     NaN
# 3               Huffer  0.658031    HUNTER  MINION   3.0     4.0     2.0
# 4           Dreadscale  0.656190    HUNTER  MINION   3.0     4.0     2.0
# 5  Steamwheedle Sniper  0.654580    HUNTER  MINION   2.0     2.0     3.0
# 6     Princess Huhuran  0.646123    HUNTER  MINION   5.0     6.0     5.0
# 7         Stablemaster  0.641064    HUNTER  MINION   3.0     4.0     2.0
# 8            Powershot  0.635938    HUNTER   SPELL   3.0     NaN     NaN
# 9        Lock and Load  0.633210    HUNTER   SPELL   2.0     NaN     NaN
#
#                                                 text
# 0  Whenever another minion takes damage, destroy it.
# 1                      Summon three 1/1 Webspinners.
# 2  Give a friendly Beast +2 Attack and <b>Immune<...
# 3                                      <b>Charge</b>
# 4  At the end of your turn, deal 1 damage to all ...
# 5                Your Hero Power can target minions.
# 6  <b>Battlecry:</b> Trigger a friendly minion's ...
# 7  <b>Battlecry:</b> Give a friendly Beast <b>Imm...
# 8  Deal $2 damage to a minion and the minions nex...
# 9  Each time you cast a spell this turn, add a ra...

# %%
sim=w2v.most_similar(positive=['Steady_Shot', 'Flametongue_Totem'], negative=['Totemic_Call'])
tt=pd.DataFrame(sim)
sim_df=pd.DataFrame({"name":tt[0].apply(lambda n:n.replace("_"," ")),"sim":tt[1]})
sim_df=pd.merge(sim_df,meta.drop_duplicates('name'),on='name')
sim_df[["name","sim","cardClass","type","cost","attack","health","text"]]
# Out:
#                   name       sim cardClass    type  cost  attack  health  \
# 0     Animal Companion  0.772825    HUNTER   SPELL   3.0     NaN     NaN
# 1         Kill Command  0.767148    HUNTER   SPELL   3.0     NaN     NaN
# 2   Unleash the Hounds  0.765869    HUNTER   SPELL   3.0     NaN     NaN
# 3       Explosive Trap  0.764168    HUNTER   SPELL   2.0     NaN     NaN
# 4        Eaglehorn Bow  0.757350    HUNTER  WEAPON   3.0     3.0     NaN
# 5  Professor Putricide  0.744551   NEUTRAL    HERO   NaN     NaN    30.0
# 6         Big Bad Wolf  0.739669    HUNTER  MINION   2.0     3.0     2.0
# 7    Savannah Highmane  0.738990    HUNTER  MINION   6.0     6.0     5.0
# 8          Houndmaster  0.736163    HUNTER  MINION   4.0     4.0     3.0
# 9           Gahz'rilla  0.733699    HUNTER  MINION   7.0     6.0     9.0
#
#                                                 text
# 0                   Summon a random Beast Companion.
# 1  Deal $3 damage. If you control a Beast, deal\n...
# 2  For each enemy minion, summon a 1/1 Hound with...
# 3  <b>Secret:</b> When your hero is attacked, dea...
# 4  [x]Whenever a friendly\n<b>Secret</b> is revea...
# 5                                                NaN
# 6                                                NaN
# 7         <b>Deathrattle:</b> Summon two 2/2 Hyenas.
# 8  <b>Battlecry:</b> Give a friendly Beast +2/+2 ...
# 9  Whenever this minion takes damage, double its ...

# %%
sim=w2v.most_similar(positive=['Steady_Shot', 'Windfury'], negative=['Totemic_Call'])
tt=pd.DataFrame(sim)
sim_df=pd.DataFrame({"name":tt[0].apply(lambda n:n.replace("_"," ")),"sim":tt[1]})
sim_df=pd.merge(sim_df,meta.drop_duplicates('name'),on='name')
sim_df[["name","sim","cardClass","type","cost","attack","health","text"]]
# Out:
#                name       sim cardClass    type  cost  attack  health  \
# 0  Silithid Swarmer  0.704006   NEUTRAL  MINION   3.0     3.0     5.0
# 1      Stablemaster  0.695898    HUNTER  MINION   3.0     4.0     2.0
# 2  Piranha Launcher  0.678687    HUNTER  WEAPON   5.0     2.0     NaN
# 3           Acidmaw  0.651499    HUNTER  MINION   7.0     4.0     2.0
# 4   Forlorn Stalker  0.650588    HUNTER  MINION   3.0     4.0     2.0
# 5        Core Rager  0.646585    HUNTER  MINION   4.0     4.0     4.0
# 6       Arcane Shot  0.641741    HUNTER   SPELL   1.0     NaN     NaN
# 7         Dart Trap  0.640669    HUNTER   SPELL   2.0     NaN     NaN
# 8        Cobra Shot  0.635009    HUNTER   SPELL   5.0     NaN     NaN
# 9      Misdirection  0.633088    HUNTER   SPELL   2.0     NaN     NaN
#
#                                                 text
# 0   Can only attack if your hero attacked this turn.
# 1  <b>Battlecry:</b> Give a friendly Beast <b>Imm...
# 2  [x]After your hero attacks,\nsummon a 1/1 Pira...
# 3  Whenever another minion takes damage, destroy it.
# 4  <b>Battlecry:</b> Give all <b>Deathrattle</b> ...
# 5  <b>Battlecry:</b> If your hand is empty, gain ...
# 6                                    Deal $2 damage.
# 7  <b>Secret:</b> After an opposing Hero Power is...
# 8     Deal $3 damage to a minion and the enemy hero.
# 9  <b>Secret:</b> When an enemy attacks your hero...

# %%
sim=w2v.most_similar(positive=["Gahz'rilla", "C'Thun's_Chosen"], negative=["C'Thun"])
tt=pd.DataFrame(sim)
sim_df=pd.DataFrame({"name":tt[0].apply(lambda n:n.replace("_"," ")),"sim":tt[1]})
sim_df=pd.merge(sim_df,meta.drop_duplicates('name'),on='name')
sim_df[["name","sim","cardClass","type","cost","attack","health","text"]]
# Out:
#                    name       sim cardClass    type  cost  attack  health  \
# 0                 Snake  0.875436    HUNTER  MINION   1.0     1.0     1.0
# 1                Spider  0.823119    HUNTER  MINION   1.0     1.0     1.0
# 2          Big Bad Wolf  0.822711    HUNTER  MINION   2.0     3.0     2.0
# 3   Steamwheedle Sniper  0.818254    HUNTER  MINION   2.0     2.0     3.0
# 4               Malorne  0.816947     DRUID  MINION   7.0     9.0     7.0
# 5          Cat in a Hat  0.816743    HUNTER  MINION   3.0     4.0     2.0
# 6  Grotesque Dragonhawk  0.815386   NEUTRAL  MINION   7.0     5.0     5.0
# 7                 Misha  0.801585    HUNTER  MINION   0.0     4.0     4.0
# 8        King of Beasts  0.799415    HUNTER  MINION   5.0     2.0     6.0
# 9              Tabbycat  0.795876    HUNTER  MINION   1.0     1.0     1.0
#
#                                                 text
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                Your Hero Power can target minions.
# 4  <b>Deathrattle:</b> Shuffle this minion into y...
# 5                                     <b>Stealth</b>
# 6                                    <b>Windfury</b>
# 7                                       <b>Taunt</b>
# 8  <b>Taunt</b>. <b>Battlecry:</b> Gain +1 Attack...
# 9                                                NaN

# %% [markdown]
# ## Encodage des information numérique / catégorielle sur les cartes ?
# Predire le cout, l'attaque la défense, la catégorie à l'aide de classifieur simples

# %% [markdown]
# ## Modèles de prédiction de résultats des matchs

# %%
match_results = [sentence.split(',')[1] for sentence in corpus_all]
y=np.array(np.array(match_results)=='win',np.int)

# %%
# nombre de serie
nbseries=len(y)
nbseries
# Out:
# 396238

# %%
# longueur des series
sl = np.array([len(sentence.split(',')) for sentence in corpus_all])
hi=plt.hist(sl[sl<100],range(100))

# %%
X = np.zeros((nbseries,80))
Y = np.zeros((nbseries,80,1))

# %%
for s in range(nbseries):
    for c in range(np.min([len(corpus_num[s]),80])):
        if(len(corpus_num[s])>5):
            X[s,c]=corpus_num[s][c]
            Y[s,c,0]=y[s]

# %%
from keras.layers import *
nbneurones = 200
cards=Input(shape=(80,), dtype='int32')
embedding = Embedding(V, vector_dim, input_length=80, name='embedding',mask_zero=True,weights=[SkipGram.get_weights()[0]],trainable=False)
target = embedding(cards)
gruG = GRU(nbneurones,return_sequences=True, input_shape=(80, vector_dim),activation='relu')(target)
pred = TimeDistributed(Dense(1,activation='sigmoid'))(gruG)
gru  = Model(inputs=cards,outputs=pred)
gru.compile(loss='binary_crossentropy', optimizer='adam',metrics=["acc"])

# %%
gru.fit(X,Y,epochs=10)

# %%
ival = np.random.choice(nbseries,int(np.round(0.05*nbseries)), replace=False)
Xval = X[ival,:]
yval = y[ival]
iapp = np.setdiff1d(range(nbseries),ival)
Xapp = X[iapp,:]
yapp = y[iapp]

# %%
def match_seq_generator(Xapp,yapp,nbm):
    while 1:
        ns = Xapp.shape[0]-1
        ibatch = np.random.choice(ns,nbm, replace=False)
        yield (Xapp[ibatch,:],yapp[ibatch])

# %%
from keras.layers import *
nbneurones = 400
cards=Input(shape=(80,), dtype='int32')
embedding = Embedding(V, vector_dim, input_length=80, name='embedding',mask_zero=True,weights=[SkipGram.get_weights()[0]],trainable=False)
target = embedding(cards)
gruG = GRU(nbneurones, input_shape=(80, vector_dim))(target)
pred = Dense(1,activation='sigmoid')(gruG)
gruLast  = Model(inputs=cards,outputs=pred)
gruLast.compile(loss='binary_crossentropy', optimizer='adam',metrics=["acc"])

# %%
gruLast.fit_generator(match_seq_generator(Xapp,yapp,50),200,epochs=60,validation_data=[Xval,yval])
# Out:
# Epoch 1/60
# 200/200 [==============================] - 85s - loss: 0.6742 - acc: 0.5810 - val_loss: 0.6619 - val_acc: 0.6092
# Epoch 2/60
# 200/200 [==============================] - 89s - loss: 0.6559 - acc: 0.6113 - val_loss: 0.6467 - val_acc: 0.6275
# Epoch 3/60
# 200/200 [==============================] - 85s - loss: 0.6517 - acc: 0.6221 - val_loss: 0.6523 - val_acc: 0.6080
# Epoch 4/60
# 200/200 [==============================] - 85s - loss: 0.6411 - acc: 0.6352 - val_loss: 0.6583 - val_acc: 0.6120
# Epoch 5/60
# 200/200 [==============================] - 85s - loss: 0.6431 - acc: 0.6303 - val_loss: 0.6396 - val_acc: 0.6354
# Epoch 6/60
# 200/200 [==============================] - 85s - loss: 0.6382 - acc: 0.6354 - val_loss: 0.6349 - val_acc: 0.6418
# Epoch 7/60
# 200/200 [==============================] - 84s - loss: 0.6340 - acc: 0.6386 - val_loss: 0.6328 - val_acc: 0.6448
# 200/200 [==============================] - 89s - loss: 0.5817 - acc: 0.6922 - val_loss: 0.5893 - val_acc: 0.6824
# Epoch 53/60
# 200/200 [==============================] - 85s - loss: 0.5763 - acc: 0.6983 - val_loss: 0.5921 - val_acc: 0.6800
# Epoch 54/60
# 200/200 [==============================] - 86s - loss: 0.5787 - acc: 0.6907 - val_loss: 0.5889 - val_acc: 0.6814
# Epoch 55/60
# 200/200 [==============================] - 85s - loss: 0.5741 - acc: 0.6985 - val_loss: 0.5925 - val_acc: 0.6817
# Epoch 56/60
# 200/200 [==============================] - 85s - loss: 0.5768 - acc: 0.6890 - val_loss: 0.5890 - val_acc: 0.6856
# Epoch 57/60
# 200/200 [==============================] - 85s - loss: 0.5791 - acc: 0.6929 - val_loss: 0.5877 - val_acc: 0.6859
# Epoch 58/60
# 200/200 [==============================] - 85s - loss: 0.5797 - acc: 0.6892 - val_loss: 0.5863 - val_acc: 0.6878
# Epoch 59/60
# 200/200 [==============================] - 85s - loss: 0.5740 - acc: 0.7007 - val_loss: 0.5862 - val_acc: 0.6874
# Epoch 60/60
# 200/200 [==============================] - 86s - loss: 0.5751 - acc: 0.6970 - val_loss: 0.5932 - val_acc: 0.6818

# %%
df=pd.read_csv("./matchs200k.csv",header=None)
df.columns=["gid","player","name","result","turn","cardid"]

# %%
df["w"]=1
nbc=df[["gid","w"]].groupby("gid").sum()

# %%
h=plt.hist(nbc.loc[nbc["w"]<200,"w"],50)

# %%
nbgames    = int(df["gid"].max())+1
gamelength = 125

# %%
df["resnum"]=(df["result"]=="win")
df["playernum"]=(df["player"]=="me")
dfr=df[["gid","resnum"]].groupby("gid").max()
ym=np.array(dfr["resnum"],np.int)

# %%
Xc = np.zeros((nbgames,gamelength))
Xp = np.zeros((nbgames,gamelength,1))
Ym = np.zeros((nbgames,gamelength,1))

# %%
df['cardnum'] = df.groupby(['gid']).cumcount()

# %%
cards = df["name"].unique()
V = len(cards)
cards_dict = dict((cards[i-1],i) for i in xrange(1, V+1))

# %%
dfc    = df.loc[df['cardnum']<125,:]
gind   = np.array(dfc["gid"],np.int)
cind   = np.array(dfc["cardnum"],np.int)
def encodecard(c):
        return cards_dict[c]
card   = np.array(dfc["name"].apply(encodecard),np.int)
player = np.array(dfc["player"]=="me",np.int)

# %%
Xc[gind,cind]=card
Xp[gind,cind,0]=player

# %%
for g in range(nbgames):
    Ym[g,:,0]=ym[g]

# %%
nbneurones = 400
vector_dim = 64
cards=Input(shape=(gamelength,), dtype='int32')
embedding = Embedding(V+1, vector_dim, input_length=gamelength, name='embedding',mask_zero=True)
target = embedding(cards)
player=Input(shape=(gamelength,1,))
x = Concatenate()([target,player])
gruG = GRU(nbneurones, input_shape=(gamelength, vector_dim+1))(x)
pred = Dense(1,activation='sigmoid')(gruG)
gruLast  = Model(inputs=[cards,player],outputs=pred)
gruLast.compile(loss='binary_crossentropy', optimizer='adam',metrics=["acc"])

# %%
ival = np.random.choice(nbgames,int(np.round(0.02*nbgames)), replace=False)
Xcval = Xc[ival,:]
Xpval = Xp[ival,:,:]
ymval = ym[ival]
Ymval = Ym[ival,:,:]
iapp = np.setdiff1d(range(nbgames),ival)
Xcapp = Xc[iapp,:]
Xpapp = Xp[iapp,:,:]
ymapp = ym[iapp]
Ymapp = Ym[iapp,:,:]

# %%
def match_seq_generator(Xcapp,Xpapp,ymapp,nbm):
    while 1:
        ns = Xcapp.shape[0]
        ibatch = np.random.choice(ns,nbm, replace=False)
        yield ([Xcapp[ibatch,:],Xpapp[ibatch,:,:]],ymapp[ibatch])

# %%
#gruLast.fit(x=[Xcapp,Xpapp],y=ymapp,epochs=1)
hist=gruLast.fit_generator(match_seq_generator(Xcapp,Xpapp,ymapp,50),100,epochs=60,validation_data=[[Xcval,Xpval],ymval])
# Out:
# Epoch 1/60
# 100/100 [==============================] - 51s - loss: 0.6405 - acc: 0.6724 - val_loss: 0.6065 - val_acc: 0.7140
# Epoch 2/60
# 100/100 [==============================] - 51s - loss: 0.5867 - acc: 0.7280 - val_loss: 0.5982 - val_acc: 0.7140
# Epoch 3/60
# 100/100 [==============================] - 51s - loss: 0.5990 - acc: 0.7058 - val_loss: 0.5912 - val_acc: 0.7140
# Epoch 4/60
# 100/100 [==============================] - 50s - loss: 0.5797 - acc: 0.7170 - val_loss: 0.5673 - val_acc: 0.7234
# Epoch 5/60
# 100/100 [==============================] - 50s - loss: 0.5448 - acc: 0.7348 - val_loss: 0.5229 - val_acc: 0.7433
# Epoch 6/60
# 100/100 [==============================] - 50s - loss: 0.5393 - acc: 0.7396 - val_loss: 0.5113 - val_acc: 0.7479
# Epoch 7/60
# 100/100 [==============================] - 50s - loss: 0.4989 - acc: 0.7610 - val_loss: 0.4816 - val_acc: 0.7711
# Epoch 8/60
# 100/100 [==============================] - 51s - loss: 0.4859 - acc: 0.7720 - val_loss: 0.4678 - val_acc: 0.7766
# Epoch 9/60
# 100/100 [==============================] - 52s - loss: 0.4773 - acc: 0.7744 - val_loss: 0.4847 - val_acc: 0.7741
# Epoch 10/60
# 100/100 [==============================] - 51s - loss: 0.4456 - acc: 0.7960 - val_loss: 0.4467 - val_acc: 0.7963
# Epoch 11/60
# 100/100 [==============================] - 51s - loss: 0.4264 - acc: 0.8100 - val_loss: 0.4378 - val_acc: 0.8016
# Epoch 12/60
# 100/100 [==============================] - 51s - loss: 0.4240 - acc: 0.8012 - val_loss: 0.4315 - val_acc: 0.8011
# Epoch 13/60
# 100/100 [==============================] - 51s - loss: 0.4267 - acc: 0.8052 - val_loss: 0.4451 - val_acc: 0.7910
# Epoch 14/60
# 100/100 [==============================] - 51s - loss: 0.4062 - acc: 0.8214 - val_loss: 0.4145 - val_acc: 0.8097
# Epoch 15/60
# 100/100 [==============================] - 52s - loss: 0.4078 - acc: 0.8178 - val_loss: 0.4171 - val_acc: 0.8099
# Epoch 16/60
# 100/100 [==============================] - 51s - loss: 0.4034 - acc: 0.8170 - val_loss: 0.4083 - val_acc: 0.8221
# Epoch 17/60
# 100/100 [==============================] - 51s - loss: 0.4070 - acc: 0.8154 - val_loss: 0.4071 - val_acc: 0.8170
X_embedded.shape
# Out:
# (1642, 2)

# %%
useCards=pd.DataFrame({'name':df["name"].unique(),'t0':X_embedded[1:,0],'t1':X_embedded[1:,1]})
meta_sub=pd.merge(useCards,meta.drop_duplicates('name'),on='name')

# %%
classes=meta_sub["cardClass"].unique()
class_dict=dict((classes[i],i) for i in range(len(classes)))
meta_sub["card_class_num"]=meta_sub["cardClass"].apply(lambda c:class_dict[c])
cm=plt.get_cmap("tab20")
plt.scatter(meta_sub["t0"],meta_sub["t1"],s=meta_sub["cost"]*10,color=cm(meta_sub["card_class_num"]))

# %%
def match_seq_generator(Xcapp,Xpapp,ymapp,nbm):
    while 1:
        ns = Xcapp.shape[0]
        ibatch = np.random.choice(ns,nbm, replace=False)
        yield ([Xcapp[ibatch,:],Xpapp[ibatch,:,:]],ymapp[ibatch,:,:])

# %%
nbneurones = 400
vector_dim = 64
cards=Input(shape=(gamelength,), dtype='int32')
embedding = Embedding(V+1, vector_dim, input_length=gamelength, name='embedding',mask_zero=True)
target = embedding(cards)
player=Input(shape=(gamelength,1,))
x = Concatenate()([target,player])
gruG = GRU(nbneurones, return_sequences=True,input_shape=(gamelength, vector_dim+1))(x)
pred = TimeDistributed(Dense(1,activation='sigmoid'))(gruG)
gruFull  = Model(inputs=[cards,player],outputs=pred)
gruFull.compile(loss='binary_crossentropy', optimizer='adam',metrics=["acc"])

# %%
hist=gruFull.fit_generator(match_seq_generator(Xcapp,Xpapp,Ymapp,100),100,epochs=100,validation_data=[[Xcval,Xpval],Ymval])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 85s - loss: 0.6905 - acc: 0.5353 - val_loss: 0.6909 - val_acc: 0.5310
# Epoch 2/100
# 100/100 [==============================] - 83s - loss: 0.6894 - acc: 0.5385 - val_loss: 0.6909 - val_acc: 0.5313
# Epoch 3/100
# 100/100 [==============================] - 85s - loss: 0.6879 - acc: 0.5461 - val_loss: 0.6908 - val_acc: 0.5330
# Epoch 4/100
# 100/100 [==============================] - 83s - loss: 0.6905 - acc: 0.5302 - val_loss: 0.6899 - val_acc: 0.5340
# Epoch 5/100
# 100/100 [==============================] - 84s - loss: 0.6892 - acc: 0.5371 - val_loss: 0.6890 - val_acc: 0.5361
# Epoch 6/100
# 100/100 [==============================] - 84s - loss: 0.6861 - acc: 0.5537 - val_loss: 0.6897 - val_acc: 0.5385
# Epoch 7/100
# 100/100 [==============================] - 84s - loss: 0.6914 - acc: 0.5326 - val_loss: 0.6871 - val_acc: 0.5424
# Epoch 8/100
# 100/100 [==============================] - 83s - loss: 0.6804 - acc: 0.5652 - val_loss: 0.6783 - val_acc: 0.5715
# Epoch 9/100
# 100/100 [==============================] - 84s - loss: 0.6756 - acc: 0.5759 - val_loss: 0.6746 - val_acc: 0.5797
# Epoch 10/100
# 100/100 [==============================] - 84s - loss: 0.6698 - acc: 0.5882 - val_loss: 0.6686 - val_acc: 0.5856
# Epoch 11/100
# 100/100 [==============================] - 84s - loss: 0.6622 - acc: 0.6009 - val_loss: 0.6713 - val_acc: 0.5878
